# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
plt.style.use('plot_style.txt')
from matplotlib.ticker import ScalarFormatter,AutoMinorLocator
import matplotlib as mpl

colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061']
dashesStyles = [[3,1],
            [1000,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1]]

# %%
applicants=pd.read_excel("Applicants.xlsx")
tasks=pd.read_excel("Tasks.xlsx")

# %%
x=applicants[["x_coord"]].to_numpy()
y=applicants[["y_coord"]].to_numpy()
x_t=tasks[["x_coord"]].to_numpy()
y_t=tasks[["y_coord"]].to_numpy()

# %%
plt.scatter(x, y, c='green', alpha=0.8,s=1,label="Volunteers")
plt.scatter(x_t,y_t, c="red",alpha=0.8,s=40,label="Tasks",marker="*")

# plt.title('Locations in 2D Plane')
plt.legend(loc='best',fontsize=11)
plt.xlabel('x-axis',)
plt.ylabel('y-axis')
plt.savefig('D:\\python_apps\\MTP\\Plots\\location_dist.eps', format='eps',dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
# fig = plt.subplots(figsize =(15, 8))
x_axis = [300,600,900,1200,1500]


a=[5.75,6.77,8.55,10.5,12.4] ########################
color="blue"
label="Our Framework"        #############################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)

a=[54,67,92,124,132]
color="red"
label="OG"             ########################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)


a=[2.75,3.9,5.62,6.11,7.05] ########################
color="brown"
label="GMA"        #############################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)


plt.legend(fontsize=15)
# plt.title("Total utility") ########################
plt.xlabel("Number of candidates")
plt.ylabel("Execution Time (in seconds)") #########################
plt.savefig('D:\\python_apps\\MTP\\Plots\\execution_time.eps', format='eps',dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
x_axis = [300,600,900,1200,1500]

a=[0.66,0.82,1.14,1.57,1.99] ########################
color="blue"
label="Our Framework"        #############################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)

a=[0.42,0.71,0.861,0.99,1.04]
color="red"
label="OG"             ########################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)



a=[0.22,0.32,0.49,0.61,0.65] ########################
color="brown"
label="GMA"        #############################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)


plt.legend(fontsize=15)
# plt.title("Total utility") ########################
plt.xlabel("Number of candidates")
plt.ylabel("Net Utilty") #########################
plt.savefig('D:\\python_apps\\MTP\\Plots\\netutility.eps', format='eps',dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
x_axis = [300,600,900,1200,1500]

a=[13.4,15.46,19.58,21.65,22.68] ########################
color="blue"
label="Our Framework"        #############################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)


a=[10,12.6,15.89,17.69,20]
color="red"
label="OG"             ########################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)


a=[11.69,12.3,14.56,16.1,17.99] ########################
color="brown"
label="GMA"        #############################
plt.plot(x_axis,a,color=color)
plt.scatter(x_axis,a,color=color)
plt.plot([], [], '-o', color=color, label = label)


plt.legend(fontsize=15)
# plt.title("Total utility") ########################
plt.xlabel("Number of candidates")
plt.ylabel("Success Rate") #########################
plt.savefig('D:\\python_apps\\MTP\\Plots\\sr.eps', format='eps',dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
